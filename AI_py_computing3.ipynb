# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeunseok97/python_start/blob/main/AI_py_computing3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

def info(x):
  return type(x)

# %%
# 리스트는 수치연산용이 아니다

A =  [1,2,3,4]
B =  [3,4,5,6]
A*B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4cfd6778f1c0> in <cell line: 5>()
#       3 A =  [1,2,3,4]
#       4 B =  [3,4,5,6]
# ----> 5 A*B
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
a = np.array(A)
print(a)
b = np.array(B)
print(b)

np.dot(a,b)
# Out:
# [1 2 3 4]
# [3 4 5 6]
# 50

# %% [markdown]
# pd pandas  데이터 관리 라이브러리
# - 변수선택
# - 데이터 필터, 특정 조건을 만족하는 관측치 고르기
# - 정렬
# - 병합
# - 새 변수 생성
# - pivot table
#  - 기본에서는 안되니 pandas를 불러서 함.

# %%
# 파일 업로딩 코드
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9301f286-b294-4a4c-818d-aa90284ada49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9301f286-b294-4a4c-818d-aa90284ada49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("test.csv")
df
# Out:
#   col1 col2  col3
# 0    a    b     1
# 1    a    b     2
# 2    c    d     3

# %% [markdown]
# #데이터 받았을 때 글자가 깨졌는지 확인하는 방법으로 head나 tail을 쓴다

# %%
df.head(1) # 처음 보기
# Out:
#   col1 col2  col3
# 0    a    b     1

# %%
df.tail(1) # 끝 줄 보기
# Out:
#   col1 col2  col3
# 2    c    d     3

# %%
# 데이터 프레임을 프로그램내에서 정의하는 방법

names = ["Olga", "Andrew", "Brian"," Telulah","Nicole","Tilda"]
ages = [29,21,45,23,39,46]
married=[False,True,True,False,True,True]

# %%
#pandasseries: 한 변수 객체
ser= pd.Series(names,name = "name")
print(ser)
# Out:
# 0        Olga
# 1      Andrew
# 2       Brian
# 3     Telulah
# 4      Nicole
# 5       Tilda
# Name: name, dtype: object

# %%
df = pd.DataFrame({"name": names,"age":ages,"married":married})
df
# Out:
#        name  age  married
# 0      Olga   29    False
# 1    Andrew   21     True
# 2     Brian   45     True
# 3   Telulah   23    False
# 4    Nicole   39     True
# 5     Tilda   46     True

# %%
ser.iloc[2]
# iloc는 인덱스, 컬럼
df.iloc[2,0]

ser.shape
df.shape
for i in df.columns:
  print(i)
# Out:
# name
# age
# married

# %%
dataurl = 'https://andybek.com/pandas-nutrition'
nu = pd.read_csv(dataurl)
nu.head(10)

nu["Unnamed: 0"]
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 8784    8784
# 8785    8785
# 8786    8786
# 8787    8787
# 8788    8788
# Name: Unnamed: 0, Length: 8789, dtype: int64

# %%
nu.head(3)
# Out:
#             name serving_size  calories total_fat saturated_fat cholesterol  \
# 0     Cornstarch        100 g       381      0.1g           NaN           0
# 1   Nuts, pecans        100 g       691       72g          6.2g           0
# 2  Eggplant, raw        100 g        25      0.2g           NaN           0
#
#     sodium  choline     folate folic_acid  ...      fat saturated_fatty_acids  \
# 0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g               0.009 g
# 1  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g               6.180 g
# 2  2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g               0.034 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.025 g
# 1                    40.801 g                    21.614 g
# 2                     0.016 g                     0.076 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# ...

# %%
nu.axes
#컬럼, 인덱스
nu.axes[1][2]
#nu.set_index("name", inplace = True)
nu.shape
# Out:
# (8789, 75)

# %%
nu.head(1)
# Out:
#            serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch        100 g       381      0.1g           NaN           0
#
#              sodium choline    folate folic_acid    niacin  ...     fat  \
# name                                                        ...
# Cornstarch  9.00 mg  0.4 mg  0.00 mcg   0.00 mcg  0.000 mg  ...  0.05 g
#
#            saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch               0.009 g                     0.016 g
#
#            polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                     0.025 g                 0.00 mg   0.0 g
#
#                ash caffeine theobromine   water
# name
# Cornstarch  0.09 g  0.00 mg     0.00 mg  8.32 g
#
# [1 rows x 75 columns]

# %%
nu.loc["Eggplant, raw"]
#인덱스 범위 , 컬럼 범위
nu.loc["Eggplant, raw":"Sherbet, orange", "calories":"cholesterol"]
# Out:
#                  calories total_fat saturated_fat cholesterol
# name
# Eggplant, raw          25      0.2g           NaN           0
# Teff, uncooked        367      2.4g          0.4g           0
# Sherbet, orange       144        2g          1.2g         1mg

# %%
nu.loc[["Raspberries, raw", "Blackberries, raw"],["protein", "vitamin_b6","water"]]
# Out:
#                   protein vitamin_b6    water
# name
# Raspberries, raw   1.20 g   0.055 mg  85.75 g
# Blackberries, raw  1.39 g   0.030 mg  88.15 g

# %%
#iloc 메소드 : 데이터의 서브셋을 인덕스 번호 기반으로 뽑는다.
nu.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
#iloc 메소드 : 데이터의 서브셋을 인덕스 번호 기반으로 뽑는다.
#인덱스 컬럼
nu.iloc[2][3:5]
# Out:
# saturated_fat    NaN
# cholesterol        0
# Name: Eggplant, raw, dtype: object

# %%
new_nu = nu.iloc[
    [True if i%2 ==0 else False for i in range(8789)],
    [True if i%2 ==0 else False for i in range(75)]
]
new_nu.head(5)
# Out:
#                   serving_size total_fat cholesterol  choline folic_acid  \
# name
# Cornstarch               100 g      0.1g           0   0.4 mg   0.00 mcg
# Eggplant, raw            100 g      0.2g           0   6.9 mg   0.00 mcg
# Sherbet, orange          100 g        2g         1mg   7.7 mg   0.00 mcg
# Taro leaves, raw         100 g      0.7g           0  12.8 mg   0.00 mcg
# Cheese, camembert        100 g       24g        72mg  15.4 mg   0.00 mcg
#
#                   pantothenic_acid   thiamin vitamin_a_rae carotene_beta  \
# name
# Cornstarch                0.000 mg  0.000 mg      0.00 mcg      0.00 mcg
# Eggplant, raw             0.281 mg  0.039 mg      1.00 mcg     14.00 mcg
# Sherbet, orange           0.224 mg  0.027 mg     12.00 mcg      1.00 mcg
# Taro leaves, raw          0.084 mg  0.209 mg    241.00 mcg   2895.00 mcg
# Cheese, camembert         1.364 mg  0.028 mg    241.00 mcg     12.00 mcg
#
# ...

# %%
# 조건식 걸기
data_url = 'https://andybek.com/pandas-soccer'

players=pd.read_csv(data_url)
players.info()
players.dtypes.value_counts()
players.sample(5)
players.dtypes.value_counts()
players.market_value>40



#dtypes 각 데이터의 형태
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          465 non-null    object
#  1   club          465 non-null    object
#  2   age           465 non-null    int64
#  3   position      464 non-null    object
#  4   position_cat  465 non-null    int64
#  5   market_value  462 non-null    float64
#  6   page_views    465 non-null    int64
#  7   fpl_value     465 non-null    float64
#  8   fpl_sel       465 non-null    object
#  9   fpl_points    465 non-null    int64
#  10  region        465 non-null    int64
#  11  nationality   465 non-null    object
#  12  new_foreign   465 non-null    int64
#  13  age_cat       465 non-null    int64
#  14  club_id       465 non-null    int64
#  15  big_club      465 non-null    int64
#  16  new_signing   465 non-null    int64
# dtypes: float64(2), int64(10), object(5)
# ...

# %%
# 데이터 필터링

LW = players[players.position=="LW"]
LW.sort_values(by=["market_value"], ascending=[False])

# players[players.market_value>40].shape
# Out:
#                          name               club  age position  position_cat  \
# 96                Eden Hazard            Chelsea   26       LW             1
# 0              Alexis Sanchez            Arsenal   28       LW             1
# 246           Raheem Sterling    Manchester+City   22       LW             1
# 219                Sadio Mane          Liverpool   25       LW             1
# 249                Leroy Sane    Manchester+City   21       LW             1
# 383             Son Heung-min          Tottenham   25       LW             1
# 153           Yannick Bolasie            Everton   28       LW             1
# 448                Andre Ayew           West+Ham   27       LW             1
# 313             DuÅ¡an TadiÄ‡        Southampton   28       LW             1
# 428              Nacer Chadli          West+Brom   27       LW             1
# 334         Marko ArnautoviÄ‡         Stoke+City   28       LW             1
# ...

# %%
#unique -> 인덱스 종류
#변수 필어틸ㅇ을 도와주는 메소드 isin, between 이런애들이 도움이 됨.
players.position.unique()
players.position.unique().size # -> len()
# Out:
# 14

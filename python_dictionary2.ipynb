# %% [markdown]
# 091 딕셔너리 생성
#
# 아래의 표에서, 아이스크림 이름을 키값으로, (가격, 재고)
#
#  리스트를 딕셔너리의 값으로 저장하라. 딕셔너리의 이름은
#
#   inventory로 한다.
#
#     이름	가격	재고
#     메로나	300	20
#     비비빅	400	3
#     죠스바	250	100

# %%
inventory = {"melona":[300,20],
             "bibibig":[400,3],
             "jawsbar":[250, 100]}
print(inventory)
# Out:
# {'melona': [300, 20], 'bibibig': [400, 3], 'jawsbar': [250, 100]}

# %% [markdown]
# 092
#
# inventory 딕셔너리에서 메로나의 가격을 화면에 출력하라.
#
#     inventory = {"메로나": [300, 20],
#               "비비빅": [400, 3],
#               "죠스바": [250, 100]}
#     실행 예시:
#     300 원

# %%
inventory = {"melona":[300,20],
             "bibibig":[400,3],
             "jawsbar":[250, 100]}
print(inventory["melona"][0],"원")
# Out:
# 300 원

# %% [markdown]
# 093
#
# inventory 딕셔너리에서 메로나의 재고를 화면에 출력하라.
#
#     inventory = {"메로나": [300, 20],
#               "비비빅": [400, 3],
#               "죠스바": [250, 100]}
#     실행 예시:
#       20 개

# %%
inventory = {"melona":[300,20],
             "bibibig":[400,3],
             "jawsbar":[250, 100]}
print(inventory["melona"][1],"개")
# Out:
# 20 개

# %% [markdown]
# 094
#
# inventory 딕셔너리에 아래 데이터를 추가하라.
#
#     inventory = {"메로나": [300, 20],
#               "비비빅": [400, 3],
#               "죠스바": [250, 100]}
#     이름	가격	재고
#     월드콘	500	7

# %%
inventory = {"melona":[300,20],
             "bibibig":[400,3],
             "jawsbar":[250, 100]}
inventory["world_corn"] = [500, 7]
print(inventory)
# Out:
# {'melona': [300, 20], 'bibibig': [400, 3], 'jawsbar': [250, 100], 'world_corn': [500, 7]}

# %% [markdown]
# 095
# 다음의 딕셔너리로부터 key 값으로만 구성된 리스트를 생성하라.
#
#     icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
ice_list = list(icecream.keys())
print(ice_list)
# Out:
# ['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나']

# %% [markdown]
# 096
#
# 다음의 딕셔너리에서 values 값으로만 구성된 리스트를
#
# 생성하라.
#
#     icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
price_list = list(icecream.values())
print(price_list)
# Out:
# [1200, 1200, 1800, 1500, 1000]

# %% [markdown]
# 097
#
# icecream 딕셔너리에서 아이스크림 판매 금액의 총합을
#
# 출력하라.
#
#     icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
#     출력 예시:
#     6700

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
print(sum(icecream.values()))
# 코랩 오류인듯
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-f44c8204177f> in <module>
#       1 icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
# ----> 2 print(sum(icecream.values()))
#
# TypeError: 'dict_values' object is not callable

# %% [markdown]
# 98
#
# 아래의 new_product 딕셔너리를 다음 icecream 딕셔너리에
#
# 추가하라.
#
#     icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
#     new_product = {'팥빙수':2700, '아맛나':1000}
#     실행 예시:
#     >> print(icecream)
#     {'탱크보이': 1200,  '폴라포': 1200,  '빵빠레': 1800,  '월드콘': 1500,  '메로나': 1000,  '팥빙수':2700, '아맛나':1000}

# %%
# 기존 딕셔너리에 update 때려박으면 기존 딕셔너리 이후에 추가됨.
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
new_product = {'팥빙수':2700, '아맛나':1000}
icecream.update(new_product)
print(icecream)
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000, '팥빙수': 2700, '아맛나': 1000}

# %% [markdown]
# 099
#
# 아래 두 개의 튜플을 하나의 딕셔너리로 변환하라. keys를
#
# 키로, vals를 값으로 result 이름의 딕셔너리로 저장한다.
#
#     keys = ("apple", "pear", "peach")
#     vals = (300, 250, 400)
#     실행 예시:
#     >> print(result)
#     {'apple': 300, 'pear': 250, 'peach': 400}

# %%
# dict(zip(key, values))로 묶으면 키랑 밸류로 짝 지어서 딕셔너리로 만듦.

keys = ("apple", "pear", "peach")
vals = (300, 250, 400)
result = dict(zip(keys,vals))
print(result)
# Out:
# {'apple': 300, 'pear': 250, 'peach': 400}

# %% [markdown]
# 100
#
# date와 close_price 두 개의 리스트를 close_table 이름의
#
# 딕셔너리로 생성하라.
#
#     date = ['09/05', '09/06', '09/07', '09/08', '09/09']
#     close_price = [10500, 10300, 10100, 10800, 11000]
#     실행 예시:
#     >> print(close_table)
#     {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}

# %%
date = ['09/05', '09/06', '09/07', '09/08', '09/09']
close_price = [10500, 10300, 10100, 10800, 11000]

close_table = dict(zip(date,close_price))
print(close_table)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}
